# %%
max_count = 115
min_count = 10

dict = {"A":2, "B":3, "C":4, "D":0}
#dict ={}

#30일 이후
#상품리스트

print("어서오세요.")

if 0 < len(dict):
    item = input("상품이름 입력 :")
    A = dict.get(item)
    if A != None:
        if 0 < dict[item]:
            dict[item] -= 1
            print("상품이 판매 되었습니다.")
        else:
            print("상품 재고가 없습니다.")
    else :
        print(item + "상품이 없습니다.")
else:
    print("매진입니다.")



#dict["A"] -= 1
#print(dict.get("A"))
# Out:
# 어서오세요.
# 상품이름 입력 :A
# 상품이 판매 되었습니다.

# %%
max_count = 115
min_count = 10

#for i in range(10, 115+1):
for i in range(min_count, max_count + 1):
    if (i%2) == 0:
        print(str(i) + " : 짝수")
    else:
        print(str(i) + " : 홀수")
# Out:
# 10 : 짝수
# 11 : 홀수
# 12 : 짝수
# 13 : 홀수
# 14 : 짝수
# 15 : 홀수
# 16 : 짝수
# 17 : 홀수
# 18 : 짝수
# 19 : 홀수
# 20 : 짝수
# 21 : 홀수
# 22 : 짝수
# 23 : 홀수
# 24 : 짝수
# 25 : 홀수
# 26 : 짝수
# 27 : 홀수
# 28 : 짝수
# 29 : 홀수
# 30 : 짝수
# 31 : 홀수
# 32 : 짝수
# 33 : 홀수
# 34 : 짝수
# 35 : 홀수
# 36 : 짝수
# 37 : 홀수
# 38 : 짝수
# 39 : 홀수
# 40 : 짝수
# 41 : 홀수
# 42 : 짝수
# 43 : 홀수
# 44 : 짝수
# 45 : 홀수
# 46 : 짝수
# 47 : 홀수
# 48 : 짝수
# 49 : 홀수
# 50 : 짝수
# 51 : 홀수
# 52 : 짝수
# 53 : 홀수
# 54 : 짝수
# 55 : 홀수
# 56 : 짝수
# 57 : 홀수
# 58 : 짝수
# 59 : 홀수
# 60 : 짝수
# 61 : 홀수
# 62 : 짝수
# 63 : 홀수
# 64 : 짝수
# 65 : 홀수
# 66 : 짝수
# 67 : 홀수
# 68 : 짝수
# 69 : 홀수
# 70 : 짝수
# 71 : 홀수
# 72 : 짝수
# 73 : 홀수
# 74 : 짝수
# 75 : 홀수
# 76 : 짝수
# 77 : 홀수
# 78 : 짝수
# 79 : 홀수
# 80 : 짝수
# 81 : 홀수
# 82 : 짝수
# 83 : 홀수
# 84 : 짝수
# 85 : 홀수
# 86 : 짝수
# 87 : 홀수
# 88 : 짝수
# 89 : 홀수
# 90 : 짝수
# 91 : 홀수
# 92 : 짝수
# 93 : 홀수
# 94 : 짝수
# 95 : 홀수
# 96 : 짝수
# 97 : 홀수
# 98 : 짝수
# 99 : 홀수
# 100 : 짝수
# 101 : 홀수
# 102 : 짝수
# 103 : 홀수
# 104 : 짝수
# 105 : 홀수
# 106 : 짝수
# 107 : 홀수
# 108 : 짝수
# ...
